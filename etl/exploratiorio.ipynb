# %%
import pandas as pd

df=pd.read_csv('../data/consolidado_raw.csv')
df
# Out:
#        id_transaccion           fecha_hora  id_usuario  id_producto  \
# 0                   1  2026-04-24T10:48:11        9318         3974
# 1                   2  2025-11-29T22:35:40        9577          125
# 2                   3  2025-03-18T04:24:26        6940         4017
# 3                   4  2024-12-25T11:39:35        8956         3189
# 4                   5  2024-12-29T03:31:12        2786          544
# ...               ...                  ...         ...          ...
# 49995           49996  2025-05-15T09:44:35        1252         4120
# 49996           49997  2025-11-12T01:28:06        7619         3982
# 49997           49998  2025-02-21T15:12:56        8362         4162
# 49998           49999  2025-03-27T00:02:22        2510          555
# 49999           50000  2025-01-24T03:45:57         763         4463
#
#        id_bodega  cantidad  precio_final_local canal_venta  clics_previos  \
# 0            313         1              942.34         Web              2
# ...

# %%
df.dtypes
# Out:
# id_transaccion                int64
# fecha_hora                   object
# id_usuario                    int64
# id_producto                   int64
# id_bodega                     int64
# cantidad                      int64
# precio_final_local          float64
# canal_venta                  object
# clics_previos                 int64
# dias_demora_real              int64
# pais                         object
# fecha_registro               object
# genero                       object
# email                        object
# nombre                       object
# categoria                    object
# marca                        object
# precio_base_usd             float64
# pais_ciudad                  object
# capacidad_almacenamiento      int64
# operador_logistico           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# id_transaccion                 0
# fecha_hora                     0
# id_usuario                     0
# id_producto                    0
# id_bodega                      0
# cantidad                       0
# precio_final_local             0
# canal_venta                    0
# clics_previos                  0
# dias_demora_real               0
# pais                           0
# fecha_registro                 0
# genero                      2439
# email                          0
# nombre                         0
# categoria                      0
# marca                          0
# precio_base_usd                0
# pais_ciudad                    0
# capacidad_almacenamiento       0
# operador_logistico             0
# dtype: int64

# %%
df['genero'].value_counts()
# Out:
# genero
# Femenino      21165
# Masculino     20952
# No binario     5444
# Name: count, dtype: int64
